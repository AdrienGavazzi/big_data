# %% [markdown]
# # T-DAT

# %% [markdown]
# Tuto docker-compose: https://www.baeldung.com/ops/kafka-docker-setup

# %% [markdown]
# Spark cluster docker-compose: https://cloudinfrastructureservices.co.uk/create-apache-spark-docker-container-using-docker-compose/

# %% [markdown]
# Spark Streaming tuto: https://www.youtube.com/playlist?list=PLe1T0uBrDrfOuXNGWSoP5KmRIN_ESkCIE

# %% [markdown]
# End to End Kafka Spark Cassandra YT: https://youtu.be/wNnTNTVdglM

# %% [markdown]
# # End to End Kafka Spark Cassandra Python Docker
# YT: https://www.youtube.com/watch?v=GqAcTrqKcrY <br>
# Git: https://github.com/airscholar/e2e-data-engineering/tree/main

# %%
import numpy as np
import yfinance as yf

# %%
name = "BTC-USD"
period = "10y"

# %%
ticker = yf.Ticker(name)
df = ticker.history(period=period)

# %%
df.Open.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
